# %% [markdown]
# #### 6.6 Sourcing & Analyzing Time-Series Data AND Time Series Forecasting in Python Bonus
#
# This script contains the following:
#
# 1. Importing your libraries and data
# 2. Subsetting, wrangling, and cleaning time-series data
# 3. Time series analysis: decomposition
#     3.1 Decompotion: Additive Model
#     3.2 Decompotion: Multiplicative Model
# 4. Testing for stationarity
# 5. Stationarizing the Data
# B. Time Series Forecasting in Python Bonus
# 1. Defining Your Parameters
# 2. Splitting the Data
# 3. Running and Fitting the Model
# 4. Iterating
#     4.1 Iteration ARIMA(8, 1, 0)
#     4.2 Try Seasonal-ARIMA

# %% [markdown]
# #### 1. Importing your libraries and data

# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm # Using .api imports the public access version of statsmodels, which is a library that handles 
# statistical models.
import os
import warnings # This is a library that handles warnings.

warnings.filterwarnings("ignore") # Disable deprecation warnings that could indicate, for instance, a suspended library or 
# feature. These are more relevant to developers and very seldom to analysts.
import gc
plt.style.use('fivethirtyeight') # This is a styling option for how your plots will appear. More examples here:
# https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html
# https://matplotlib.org/3.1.0/gallery/style_sheets/fivethirtyeight.html

# %%
# create path
path = r'/Users/macbook/Library/CloudStorage/OneDrive-Personal/Data Analisys/Boat Sales'

# %%
# import boat_data.csv
df = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'boat_sales_cleaned2.csv'), index_col=[0])

# %% [markdown]
# #### 2. Subsetting, wrangling, and cleaning time-series data

# %%
df.head(5)
# Out:
#               Boat Type            Manufacturer                 Type  \
# 1   Center console boat       Terhi power boats  new boat from stock
# 4          Fishing Boat      Linder power boats  new boat from stock
# 10         Fishing Boat       Terhi power boats   Used boat,Electric
# 12           Sport Boat  GS Nautica power boats            Used boat
# 13             Runabout      Kimple power boats  new boat from stock
#
#     Year Built  Length  Width       Material  Number of views last 7 days  \
# 1         2020    4.00   1.50  Thermoplastic                           75
# 4         2019    3.55   1.46      Aluminium                           58
# 10        1987    4.35   1.75            GRP                          239
# 12        2004    4.70   2.00            GRP                           69
# 13        2020    4.40   1.65      Aluminium                          113
#
#     EUR Price       Country            City Pricing Category Boat Class  \
# 1      3490.0      Germany    BÃ¶nningstedt       Low-priced    Class A
# 4      3399.0      Germany          Bayern        Low-priced    Class A
# 10     3570.0  Switzerland          Seengen       Low-priced    Class A
# 12     3500.0        Italy      Lake Garda        Low-priced    Class A
# 13     4692.0  Switzerland        Zugersee        Low-priced    Class A
#
#     Total_views           Type_split      Fuel
# 1        203469  new boat from stock       NaN
# 4        203469  new boat from stock       NaN
# 10       316879            Used boat  Electric
# 12       116749            Used boat       NaN
# 13       316879  new boat from stock       NaN

# %%
df.shape
# Out:
# (6001, 16)

# %%
df.columns
# Out:
# Index(['Boat Type', 'Manufacturer', 'Type', 'Year Built', 'Length', 'Width',
#        'Material', 'Number of views last 7 days', 'EUR Price', 'Country',
#        'City', 'Pricing Category', 'Boat Class', 'Total_views', 'Type_split',
#        'Fuel'],
#       dtype='object')

# %%
# Checking headers

pd.options.display.max_columns = None
df.head()
# Out:
#               Boat Type            Manufacturer                 Type  \
# 1   Center console boat       Terhi power boats  new boat from stock
# 4          Fishing Boat      Linder power boats  new boat from stock
# 10         Fishing Boat       Terhi power boats   Used boat,Electric
# 12           Sport Boat  GS Nautica power boats            Used boat
# 13             Runabout      Kimple power boats  new boat from stock
#
#     Year Built  Length  Width       Material  Number of views last 7 days  \
# 1         2020    4.00   1.50  Thermoplastic                           75
# 4         2019    3.55   1.46      Aluminium                           58
# 10        1987    4.35   1.75            GRP                          239
# 12        2004    4.70   2.00            GRP                           69
# 13        2020    4.40   1.65      Aluminium                          113
#
#     EUR Price       Country            City Pricing Category Boat Class  \
# 1      3490.0      Germany    BÃ¶nningstedt       Low-priced    Class A
# 4      3399.0      Germany          Bayern        Low-priced    Class A
# 10     3570.0  Switzerland          Seengen       Low-priced    Class A
# 12     3500.0        Italy      Lake Garda        Low-priced    Class A
# 13     4692.0  Switzerland        Zugersee        Low-priced    Class A
#
#     Total_views           Type_split      Fuel
# 1        203469  new boat from stock       NaN
# 4        203469  new boat from stock       NaN
# 10       316879            Used boat  Electric
# 12       116749            Used boat       NaN
# 13       316879  new boat from stock       NaN

# %%
df.dtypes
# Out:
# Boat Type                       object
# Manufacturer                    object
# Type                            object
# Year Built                       int64
# Length                         float64
# Width                          float64
# Material                        object
# Number of views last 7 days      int64
# EUR Price                      float64
# Country                         object
# City                            object
# Pricing Category                object
# Boat Class                      object
# Total_views                      int64
# Type_split                      object
# Fuel                            object
# dtype: object

# %%
df['Year Built'] = df['Year Built'].astype('str')

# %%
df.dtypes
# Out:
# Boat Type                       object
# Manufacturer                    object
# Type                            object
# Year Built                      object
# Length                         float64
# Width                          float64
# Material                        object
# Number of views last 7 days      int64
# EUR Price                      float64
# Country                         object
# City                            object
# Pricing Category                object
# Boat Class                      object
# Total_views                      int64
# Type_split                      object
# Fuel                            object
# dtype: object

# %%
# Creating a new dataframe with median prices grouped by dates

data = df.groupby('Year Built').agg({'EUR Price': ['median']})

# %%
data
# Out:
#             EUR Price
#                median
# Year Built
# 1901         89000.00
# 1910        234950.00
# 1911        175000.00
# 1912         45000.00
# 1913         12500.00
# ...               ...
# 2017        157600.00
# 2018         79900.00
# 2019         74900.00
# 2020         64495.00
# 2021        131004.16
#
# [78 rows x 1 columns]

# %%
data.columns
# Out:
# MultiIndex([('EUR Price', 'median')],
#            )

# %%
# Checking data types

data.dtypes
# Out:
# EUR Price  median    float64
# dtype: object

# %%
data.head()
# Out:
#            EUR Price
#               median
# Year Built
# 1901         89000.0
# 1910        234950.0
# 1911        175000.0
# 1912         45000.0
# 1913         12500.0

# %%
# Plotting the data using matplotlib

plt.figure(figsize=(60,15), dpi=100)
plt.plot(data)

# %%
# Reset index so that you can use the "Date" column as a filter

data = data.reset_index()

# %%
data.head()
# Out:
#   Year Built EUR Price
#                 median
# 0       1901   89000.0
# 1       1910  234950.0
# 2       1911  175000.0
# 3       1912   45000.0
# 4       1913   12500.0

# %%
df_sub = data.loc[(data['Year Built'] >= '1961-01-01') & (data['Year Built'] < '2020-06-01')]

# %%
df_sub.shape
# Out:
# (59, 2)

# %%
df_sub.columns
# Out:
# MultiIndex([('Year Built',       ''),
#             ( 'EUR Price', 'median')],
#            )

# %%
# Set the "Date" column as the index

from datetime import datetime

df_sub['datetime'] = pd.to_datetime(df_sub['Year Built']) # Create a datetime column from "Date.""
df_sub = df_sub.set_index('datetime') # Set the datetime as the index of the dataframe.
df_sub.drop(['Year Built'], axis=1, inplace=True) # Drop the "Date" column.
df_sub.head()
# Out:
#            EUR Price
#               median
# datetime
# 1962-01-01   89760.0
# 1963-01-01   24500.0
# 1964-01-01   48610.0
# 1965-01-01   76398.0
# 1966-01-01   34500.0

# %%
# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100) # The dpi argument controls the quality of the visualization here. When it's set to 100,
# it will produce lower-than-standard quality, which is useful if, similar to this notebook, you'll have a lot of plots.
# A large number of plots will increase the size of the notebook, which could take more time to load and eat up a lot of RAM!

plt.plot(df_sub)

# %% [markdown]
# #### 3. Time series analysis: decomposition

# %% [markdown]
# ##### 3.1 Decompotion: Additive Model

# %%
# Decomposing time series using 

decomposition_adi = sm.tsa.seasonal_decompose(df_sub, model='additive')

# %%
# Defining a fixed size for all special charts

from pylab import rcParams
rcParams['figure.figsize'] = 18, 7

# %%
# Plotting decomposition of time-series data

decomposition_adi.plot()
plt.show()

# %% [markdown]
# ##### 3.2 Decompotion: Multiplicative Model

# %%
# Decompose the time series using an multiplicative model

decomposition_multi = sm.tsa.seasonal_decompose(df_sub, model='multiplicative')

# %%
# Plot the separate components

decomposition_multi.plot()
plt.show()

# %%
# Evaluating trends component from both models


decomposition_multi.trend.plot(color='red', linewidth=15, alpha=0.3)
decomposition_adi.trend.plot(color='green', linewidth=2)
plt.show()

# %% [markdown]
# ### Tryed double_exponential_smoothing

# %%
def double_exponential_smoothing(series, alpha, beta):
    """
        series - dataset with timeseries
        alpha - float [0.0, 1.0], smoothing parameter for level
        beta - float [0.0, 1.0], smoothing parameter for trend
    """
    # first value is same as series
    result = [series[0]]
    for n in range(1, len(series) + 1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series):  # forecasting
            value = result[-1]
        else:
            value = series[n]
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result


def plotDoubleExponentialSmoothing(series, alphas, betas):
    """
        Plots double exponential smoothing with different alphas and betas

        series - dataset with timestamps
        alphas - list of floats, smoothing parameters for level
        betas - list of floats, smoothing parameters for trend
    """

    with plt.style.context("seaborn-white"):
        plt.figure(figsize=(20, 8))
        for alpha in alphas:
            for beta in betas:
                plt.plot(
                    double_exponential_smoothing(series, alpha, beta),
                    label="Alpha {}, beta {}".format(alpha, beta),
                )
        plt.plot(series.values, label="Actual")
        plt.legend(loc="best")
        plt.axis("tight")
        plt.title("Double Exponential Smoothing")
        plt.grid(True)

# %%
train = df_sub[df_sub.index <= '2018-01-01'] 
test = df_sub[df_sub.index >= '2018-01-01']
test.shape
# Out:
# (3, 1)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing



# create a pandas series from the data
series = pd.Series(train[('EUR Price', 'median')])

# initialize the model
model = ExponentialSmoothing(series, trend='mul', seasonal=None, seasonal_periods=None)

# fit the model to the data
model_fit = model.fit()

# make predictions for the next 3 time steps
predictions = model_fit.forecast(steps=3).values
df_pred = test.copy()
df_pred[('EUR Price', 'median')] = predictions
# create a time series of the actual and predicted values


plt.figure(figsize=(12,4), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(df_pred, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
plotDoubleExponentialSmoothing(df_sub[('EUR Price', 'median')], alphas=[0.9], betas=[0.9, 0.8])

# %% [markdown]
# #### 4. Testing for stationarity

# %%
# The adfuller() function will import from the model from statsmodels for the test; however, running it will only return 
# an array of numbers. This is why you need to also define a function that prints the correct output from that array.

from statsmodels.tsa.stattools import adfuller # Import the adfuller() function

def dickey_fuller(timeseries): # Define the function
    # Perform the Dickey-Fuller test:
    print ('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in test[4].items():
       result['Critical Value (%s)'%key] = value
    print (result)

# Apply the test using the function on the time series
dickey_fuller(df_sub['EUR Price'])
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -3.543139
# p-value                         0.006946
# Number of Lags Used             8.000000
# Number of Observations Used    50.000000
# Critical Value (1%)            -3.568486
# Critical Value (5%)            -2.921360
# Critical Value (10%)           -2.598662
# dtype: float64

# %% [markdown]
# H0 = Unit root present (non-stationary)
# HA = Unit root not present (stationary)
# - If test statistic larger than critical value = can’t reject null hypothesis.
# - If test statistic smaller than critical value = can reject null hypothesis
#
# Using significance level of 5%, the critical Value is -2.957219. While, the test statistic is  -2.197290, which shows that it is larger than critical value. This means that the null hypothesis cannot be rejected. In other words, there is a unit root in our data and our data is non-stationary.
# Using p-value, it also shows the same result. P-value ( 0.2072307) is also larger than 0.05.

# %%
# Check out a plot of autocorrelations

from statsmodels.graphics.tsaplots import acf, plot_acf, plot_pacf # Here, you import the autocorrelation and partial correlation plots

plot_acf(df_sub, lags=30)
plt.show()

# %% [markdown]
# The test shows that there are vertical lines that go above the blue edge of the confidence interval, indicating that the lags are significantly correlated with each other and the data is non-stationary.

# %% [markdown]
# #### 05. Stationarizing Data

# %%
df_diff = df_sub - df_sub.shift(2) # The df.shift(1) function turns the observation to t-1, making the whole thing t - (t -1)
#df_diff = df_sub.copy()

# %%
df_diff.dropna(inplace = True) # Here, you remove the missing values that came about as a result of the differencing. 
# You need to remove these or you won't be able to run the Dickey-Fuller test.

# %%
df_diff.head()
# Out:
#            EUR Price
#               median
# datetime
# 1964-01-01  -41150.0
# 1965-01-01   51898.0
# 1966-01-01  -14110.0
# 1967-01-01  -23398.0
# 1968-01-01     500.0

# %%
# Check out what the differencing did to the time-series curve

plt.figure(figsize=(20,5), dpi=100)
plt.plot(df_diff)

# %%
# Re-running the Dickey-Fuller Test to check for stationarity

dickey_fuller(df_diff)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -1.808374
# p-value                         0.376312
# Number of Lags Used             8.000000
# Number of Observations Used    48.000000
# Critical Value (1%)            -3.574589
# Critical Value (5%)            -2.923954
# Critical Value (10%)           -2.600039
# dtype: float64

# %% [markdown]
# The results show that the data is now stationary. The test statistic value (-6.199769e+000) is less than the critical value (5%) of   -2.964071e+00 and the p-value is smaller than 0.05. Therefore, the test result is significant and the null hypothesis can be rejected.

# %%
# Plotting the autocorrelation again

plot_acf(df_diff)
plt.show()

# %% [markdown]
# The autocorrelation plot has improved. The stationary is strong due to no vertical lines going above the confidence interval.

# %% [markdown]
# #### B. Time Series Forecasting in Python Bonus

# %% [markdown]
# #### 1. Defining Your Parameters

# %%
# Plot partial autocorrelations to determine parameter p
plot_pacf(df_diff)
plt.figure(figsize=(15,15), dpi=300)
plt.show()

# %%
# Plot autocorrelations to determine parameter q

plot_acf(df_diff)
plt.show()

# %% [markdown]
# There are also 4 significant PACF group values. I would then take p = 4.

# %% [markdown]
# #### 2. Splitting the Data

# %%
# Split the data

train = df_diff[df_diff.index <= '2016-01-01'] 
test = df_diff[df_diff.index >= '2016-01-01']

# %%
# Plot both sets in order to see the split

plt.figure(figsize=(60,15), dpi=100)
plt.plot(train)
plt.plot(test)

# %%
test.shape
# Out:
# (5, 1)

# %% [markdown]
# ### 3. Running and Fitting the Model

# %%
from statsmodels.tsa.api import ARIMA, SARIMAX # Import the model you need

# %%
model = ARIMA(train, order=(4, 2, 3))  
fitted = model.fit()
print(fitted.summary()) # Check model summary
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       EUR Price_median   No. Observations:                   53
# Model:                 ARIMA(4, 2, 3)   Log Likelihood                -604.771
# Date:                Wed, 01 Feb 2023   AIC                           1225.543
# Time:                        09:43:33   BIC                           1240.997
# Sample:                    01-01-1964   HQIC                          1231.448
#                          - 01-01-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8522      0.346     -2.464      0.014      -1.530      -0.174
# ar.L2         -0.9959      0.198     -5.029      0.000      -1.384      -0.608
# ar.L3         -0.7505      0.406     -1.847      0.065      -1.547       0.046
# ar.L4         -0.4913      0.395     -1.242      0.214      -1.266       0.284
# ma.L1         -0.9285      0.379     -2.448      0.014      -1.672      -0.185
# ma.L2         -0.8667      0.679     -1.277      0.202      -2.197       0.464
# ma.L3          0.8074      0.437      1.845      0.065      -0.050       1.665
# sigma2      1.227e+09   6.68e-10   1.84e+18      0.000    1.23e+09    1.23e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):                34.35
# Prob(Q):                              0.90   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.60   Skew:                            -0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.05e+34. Standard errors may be unstable.

# %%
# Forecast
fc = fitted.get_forecast(5, alpha=0.05)  # 95% confidence interval  --> alpha = 0.05; 33 is the shape of the test set

# Make into pandas series
fc_series = pd.Series(fc.predicted_mean, index=test.index)
lower_series = pd.Series(fc.conf_int().iloc[:, 0], index=test.index)
upper_series = pd.Series(fc.conf_int().iloc[:, 1], index=test.index)

# %%
# Plot
plt.figure(figsize=(12,4), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.2)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# #### 4. Iterating

# %% [markdown]
# ##### 4.1 Iteration ARIMA(8, 1, 0)

# %%
model = ARIMA(train, order=(8,2, 2))  
fitted = model.fit()  
print(fitted.summary()) # Check model summary
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       EUR Price_median   No. Observations:                   53
# Model:                 ARIMA(8, 2, 2)   Log Likelihood                -604.192
# Date:                Wed, 01 Feb 2023   AIC                           1230.384
# Time:                        09:43:42   BIC                           1251.634
# Sample:                    01-01-1964   HQIC                          1238.505
#                          - 01-01-2016
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.6202      0.627     -2.583      0.010      -2.850      -0.391
# ar.L2         -2.2057      0.574     -3.845      0.000      -3.330      -1.081
# ar.L3         -2.3041      1.185     -1.945      0.052      -4.626       0.018
# ar.L4         -2.1138      0.978     -2.162      0.031      -4.030      -0.198
# ar.L5         -1.3132      0.938     -1.399      0.162      -3.153       0.526
# ar.L6         -0.7844      0.925     -0.848      0.396      -2.597       1.028
# ar.L7         -0.2947      0.940     -0.314      0.754      -2.137       1.548
# ar.L8         -0.0696      0.540     -0.129      0.897      -1.127       0.988
# ma.L1         -0.0356      0.692     -0.051      0.959      -1.392       1.321
# ma.L2         -0.9086      0.590     -1.539      0.124      -2.066       0.248
# sigma2      1.112e+09   2.65e-09   4.19e+17      0.000    1.11e+09    1.11e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                27.60
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               5.87   Skew:                            -0.40
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.95e+33. Standard errors may be unstable.

# %%
# Forecast
fc = fitted.get_forecast(5, alpha=0.05)  # 95% confidence interval  --> alpha = 0.05; 33 is the shape of the test set

# Make into pandas series
fc_series = pd.Series(fc.predicted_mean, index=test.index)
lower_series = pd.Series(fc.conf_int().iloc[:, 0], index=test.index)
upper_series = pd.Series(fc.conf_int().iloc[:, 1], index=test.index)

# %%
# Plot
plt.figure(figsize=(12,4), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.2)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# #### 4.2 Try Seasonal-ARIMA

# %%
mod = sm.tsa.SARIMAX(train, order=(1,0,0), seasonal_order=(0,1,1,12))
fitted = mod.fit()
print(fitted.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.38669D+00    |proj g|=  3.05411D-02
#
# At iterate    5    f=  9.37303D+00    |proj g|=  1.51286D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7      9      1     0     0   1.191D-06   9.373D+00
#   F =   9.3730270441646457
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                     EUR Price_median   No. Observations:                   53
# Model:             SARIMAX(1, 0, 0)x(0, 1, [1], 12)   Log Likelihood                -496.770
# Date:                              Wed, 01 Feb 2023   AIC                            999.541
# Time:                                      09:43:52   BIC                           1004.682
# Sample:                                  01-01-1964   HQIC                          1001.413
#                                        - 01-01-2016
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0135      0.162     -0.083      0.933      -0.330       0.303
# ma.S.L12      -0.4854      0.690     -0.703      0.482      -1.839       0.868
# sigma2      2.027e+09   1.13e-09   1.79e+18      0.000    2.03e+09    2.03e+09
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               356.12
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):              23.76   Skew:                            -2.54
# Prob(H) (two-sided):                  0.00   Kurtosis:                        16.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.4e+33. Standard errors may be unstable.
#  This problem is unconstrained.

# %%
# Forecast
fc = fitted.get_forecast(5, alpha=0.05)  # 95% confidence interval  --> alpha = 0.05; 33 is the shape of the test set

# Make into pandas series
fc_series = pd.Series(fc.predicted_mean, index=test.index)
lower_series = pd.Series(fc.conf_int().iloc[:, 0], index=test.index)
upper_series = pd.Series(fc.conf_int().iloc[:, 1], index=test.index)

# %%
# Plot
plt.figure(figsize=(12,4), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.2)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
gc.collect()
# Out:
# 11969
